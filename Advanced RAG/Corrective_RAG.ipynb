# %% [markdown]
# <a href="https://colab.research.google.com/github/Janardan-thapaliya/RAG/blob/main/Advanced%20RAG/Corrective_RAG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain_community langchain_openai langchain_text_splitters langchain_core langgraph pypdf faiss-cpu python-dotenv -q

# %%
from typing import List, TypedDict, Literal
from pydantic import BaseModel
import re

from langchain_community.document_loaders import PyPDFLoader
from langchain_community.vectorstores import FAISS
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_core.documents import Document
from langchain_core.prompts import ChatPromptTemplate

from langgraph.graph import StateGraph, START, END
from langchain_community.tools.tavily_search import TavilySearchResults
from dotenv import load_dotenv

# %%
# load env vars
load_dotenv()

# %%
docs = (
    PyPDFLoader("/content/book1.pdf").load()
    + PyPDFLoader("/content/book2.pdf").load()
    + PyPDFLoader("/content/book3.pdf").load()
)

# %%
UPPER_TH = 0.7
LOWER_TH = 0.3

# %%
class State(TypedDict):
    question: str
    docs: List[Document]
    good_docs: List[Document]
    verdict: str
    reason: str
    strips: List[str]
    kept_strips: List[str]
    refined_context: str
    web_query: str
    web_docs: List[Document]
    answer: str
